# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %%
df = pd.read_csv('./data/hospital_data.csv', encoding='euc-kr')

# %%
df
# Out:
#                                                  암호화요양기호         요양기관명  종별코드  \
# 0      JDQ4MTYyMiM1MSMkMSMkMCMkODkkMzgxMzUxIzExIyQxIy...  가톨릭대학교인천성모병원     1
# 1      JDQ4MTYyMiM1MSMkMSMkNCMkODkkMzgxMzUxIzExIyQxIy...        강릉아산병원     1
# 2      JDQ4MTg4MSM1MSMkMSMkMCMkODkkMzgxMzUxIzExIyQxIy...        강북삼성병원     1
# 3      JDQ4MTg4MSM1MSMkMSMkMCMkODkkMzgxMzUxIzExIyQxIy...       건국대학교병원     1
# 4      JDQ4MTYyMiM4MSMkMSMkMCMkODkkMzgxMzUxIzExIyQxIy...       경북대학교병원     1
# ...                                                  ...           ...   ...
# 76244  JDU4MTI3MSM1MSMkMSMkMCMkMTMkNDgxOTYxIzExIyQxIy...        힘나는한의원    93
# 76245  JDQ4MTg4MSM1MSMkMSMkNCMkMTMkNDgxOTYxIzUxIyQxIy...        힘내라한의원    93
# 76246  JDQ4MTg4MSM1MSMkMSMkNCMkMTMkNDgxMzUxIzUxIyQxIy...       힘찬마디한의원    93
# 76247  JDQ4MTg4MSM1MSMkMSMkNCMkMTMkMzgxNzAyIzUxIyQxIy...     힘찬세상경희한의원    93
# 76248  JDQ4MTYyMiM4MSMkMSMkNCMkMTMkNDgxMzUxIzMxIyQxIy...         힘찬한의원    93
#
#       종별코드명    시도코드 시도코드명   시군구코드 시군구코드명    읍면동   우편번호  ... 치과인턴 인원수  \
# 0      상급종합  220000    인천  220003  인천부평구    부평동  21431  ...        0
# 1      상급종합  320000    강원  320100    강릉시    NaN  25440  ...        0
# 2      상급종합  110000    서울  110016    종로구    NaN   3181  ...        0
# 3      상급종합  110000    서울  110023    광진구    NaN   5030  ...        0
# 4      상급종합  230000    대구  230006   대구중구    NaN  41944  ...        0
# ...     ...     ...   ...     ...    ...    ...    ...  ...      ...
# 76244   한의원  310000    경기  312300    김포시    NaN  10099  ...        0
# 76245   한의원  110000    서울  110003    강서구    NaN   7526  ...        0
# 76246   한의원  110000    서울  110002    강동구    천호동   5329  ...        0
# 76247   한의원  110000    서울  110014    용산구  한강로2가   4376  ...        0
# 76248   한의원  380000    경남  380500    진주시    NaN  52697  ...        0
#
#       치과레지던트 인원수 치과전문의 인원수  한방일반의 인원수  한방인턴 인원수  한방레지던트 인원수  한방전문의 인원수  \
# 0              0         1          0         0           0          0
# 1              0         2          0         0           0          0
# 2              0         4          0         0           0          0
# 3              0         3          0         0           0          0
# 4              0         1          0         0           0          0
# ...          ...       ...        ...       ...         ...        ...
# 76244          0         0          1         0           0          0
# 76245          0         0          2         0           0          0
# 76246          0         0          1         0           0          0
# 76247          0         0          0         0           0          1
# 76248          0         0          1         0           0          0
#
#        조산사 인원수       좌표(X)      좌표(Y)
# 0            0  126.724899  37.484831
# 1            0  128.857841  37.818433
# 2            0  126.967750  37.568408
# 3            0  127.071828  37.540376
# 4            0  128.604703  35.866253
# ...        ...         ...        ...
# 76244        0  126.704889  37.632495
# 76245        0  126.855061  37.561526
# 76246        0  127.126346  37.538174
# 76247        0  126.968167  37.530005
# 76248        0  128.064558  35.178636
#
# [76249 rows x 30 columns]

# %%
df.columns
# Out:
# Index(['암호화요양기호', '요양기관명', '종별코드', '종별코드명', '시도코드', '시도코드명', '시군구코드', '시군구코드명',
#        '읍면동', '우편번호', '주소', '전화번호', '병원홈페이지', '개설일자', '총의사수', '의과일반의 인원수',
#        '의과인턴 인원수', '의과레지던트 인원수', '의과전문의 인원수', '치과일반의 인원수', '치과인턴 인원수',
#        '치과레지던트 인원수', '치과전문의 인원수', '한방일반의 인원수', '한방인턴 인원수', '한방레지던트 인원수',
#        '한방전문의 인원수', '조산사 인원수', '좌표(X)', '좌표(Y)'],
#       dtype='object')

# %%
df['시도코드명'].unique()
# Out:
# array(['인천', '강원', '서울', '대구', '경남', '경기', '충남', '부산', '전북', '광주', '대전',
#        '충북', '울산', '전남', '경북', '세종시', '제주'], dtype=object)

# %%
df['시도코드명'].nunique()
# Out:
# 17

# %%
# 시도코드명별 몇개의 병원이 있는가?

# %%
location = df['시도코드명'].value_counts().index

# %%
plt.rc('font', family='Malgun Gothic')

# %%
plt.figure(figsize=(7,9))
sb.countplot(data=df, y='시도코드명', order=location)
plt.title('지역별 병원 수')
plt.xlabel('병원 수')
plt.ylabel('지역')
plt.show()
# Out:
# C:\ProgramData\anaconda3\envs\streamlit39\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\ProgramData\anaconda3\envs\streamlit39\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
# 시도코드명별 비율을 파이차트로 나타내라

# %%
location1 = df['시도코드명'].value_counts()

# %%
plt.figure(figsize=(7,7))
plt.pie(location1, autopct='%.1f', startangle=90, wedgeprops={'width':0.7})
plt.title('지역별 병원 수')
plt.legend(location1.index)
plt.show()

# %%
# 경기 지역내 병원이 가장 많은 구군 중 상위 10곳은 어디인가?

# %%
df['시도코드명'] == '경기'
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 76244     True
# 76245    False
# 76246    False
# 76247    False
# 76248    False
# Name: 시도코드명, Length: 76249, dtype: bool

# %%
gyeonggi = df.loc[df['시도코드명'] == '경기']

# %%
gyeonggi
# Out:
#                                                  암호화요양기호            요양기관명  \
# 9      JDQ4MTYyMiM1MSMkMSMkMCMkODkkMzgxMzUxIzExIyQxIy...  고려대학교의과대학부속안산병원
# 14     JDQ4MTYyMiM1MSMkMSMkMCMkODkkMzgxMzUxIzExIyQxIy...        분당서울대학교병원
# 18     JDQ4MTYyMiM1MSMkMSMkMCMkODkkMzgxMzUxIzExIyQxIy...     순천향대학교부속부천병원
# 19     JDQ4MTYyMiM1MSMkMSMkMCMkODkkMzgxMzUxIzExIyQxIy...          아주대학교병원
# 42     JDQ4MTYyMiM1MSMkMSMkMCMkODkkMzgxMzUxIzExIyQxIy...        한림대학교성심병원
# ...                                                  ...              ...
# 76215  JDU4MTI3MSM1MSMkMSMkMCMkMTMkMzgxNzAyIzMxIyQxIy...           흐를류한의원
# 76221  JDQ4MTYyMiM1MSMkMSMkMCMkMTMkNDgxMzUxIzExIyQxIy...          흥덕경희한의원
# 76238  JDU4MTI3MSM1MSMkMSMkMCMkMTMkNDgxOTYxIzExIyQyIy...            힐강한의원
# 76243  JDU4MTI3MSM1MSMkMSMkMCMkMTMkMzgxNzAyIzQxIyQxIy...            힐링한의원
# 76244  JDU4MTI3MSM1MSMkMSMkMCMkMTMkNDgxOTYxIzExIyQxIy...           힘나는한의원
#
#        종별코드 종별코드명    시도코드 시도코드명   시군구코드 시군구코드명  읍면동   우편번호  ... 치과인턴 인원수  \
# 9         1  상급종합  310000    경기  311101  안산단원구  NaN  15355  ...        0
# 14        1  상급종합  310000    경기  310403  성남분당구  NaN  13620  ...        3
# 18        1  상급종합  310000    경기  310300    부천시  NaN  14584  ...        0
# 19        1  상급종합  310000    경기  310604  수원영통구  NaN  16499  ...        4
# 42        1  상급종합  310000    경기  310702  안양동안구  NaN  14068  ...        3
# ...     ...   ...     ...   ...     ...    ...  ...    ...  ...      ...
# 76215    93   한의원  310000    경기  311901  고양덕양구  성사동  10464  ...        0
# 76221    93   한의원  310000    경기  312001  용인기흥구  NaN  16954  ...        0
# 76238    93   한의원  310000    경기  310100    광명시  NaN  14262  ...        0
# 76243    93   한의원  310000    경기  310300    부천시  NaN  14782  ...        0
# 76244    93   한의원  310000    경기  312300    김포시  NaN  10099  ...        0
#
#       치과레지던트 인원수 치과전문의 인원수  한방일반의 인원수  한방인턴 인원수  한방레지던트 인원수  한방전문의 인원수  \
# 9              0         4          0         0           0          0
# 14            10        10          0         0           0          0
# 18             0         7          0         0           0          0
# 19            13        11          0         0           0          0
# 42             7         9          0         0           0          0
# ...          ...       ...        ...       ...         ...        ...
# 76215          0         0          1         0           0          0
# 76221          0         0          1         0           0          0
# 76238          0         0          1         0           0          0
# 76243          0         0          2         0           0          0
# 76244          0         0          1         0           0          0
#
#        조산사 인원수       좌표(X)      좌표(Y)
# 9            0  126.824903  37.318514
# 14           0  127.123251  37.351981
# 18           0  126.762963  37.498700
# 19           0  127.047676  37.279393
# 42           0  126.962053  37.391757
# ...        ...         ...        ...
# 76215        0  126.838377  37.654510
# 76221        0  127.071877  37.275848
# 76238        0  126.854332  37.478704
# 76243        0  126.809590  37.471216
# 76244        0  126.704889  37.632495
#
# [16948 rows x 30 columns]

# %%
gyeonggi['시군구코드명'].value_counts()
# Out:
# 시군구코드명
# 부천시       1131
# 성남분당구      993
# 화성시        902
# 남양주시       777
# 평택시        618
# 의정부시       595
# 안양동안구      585
# 고양덕양구      554
# 김포시        551
# 시흥시        549
# 수원영통구      506
# 수원팔달구      488
# 안산단원구      483
# 용인기흥구      479
# 파주시        469
# 성남수정구      464
# 광명시        449
# 용인수지구      449
# 하남시        412
# 고양일산서구     396
# 고양일산동구     376
# 수원권선구      375
# 수원장안구      344
# 구리시        343
# 광주시        335
# 군포시        326
# 성남중원구      318
# 안양만안구      301
# 안산상록구      298
# 용인처인구      255
# 이천시        252
# 오산시        238
# 안성시        209
# 양주시        207
# 의왕시        159
# 포천시        157
# 양평군        148
# 여주시        147
# 동두천시        95
# 가평군         87
# 과천시         80
# 연천군         48
# Name: count, dtype: int64

# %%
order1 = gyeonggi['시군구코드명'].value_counts().head(10).index

# %%
order1
# Out:
# Index(['부천시', '성남분당구', '화성시', '남양주시', '평택시', '의정부시', '안양동안구', '고양덕양구', '김포시',
#        '시흥시'],
#       dtype='object', name='시군구코드명')

# %%
sb.countplot(data= df, x='시군구코드명', order=order1)
ax = sb.countplot(data=df, x='시군구코드명', order=order1)
for p in ax.patches:
    height = p.get_height()
    ax.text(x = p.get_x() + p.get_width() / 2, 
            y = height + 20, 
            s = int(height), 
            ha = 'center', 
            size = 9)
ax.set_ylim(0, 1200)
plt.xticks(rotation = 60)
plt.xlabel('지역')
plt.ylabel('갯수')
plt.show()
# Out:
# C:\ProgramData\anaconda3\envs\streamlit39\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\ProgramData\anaconda3\envs\streamlit39\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\ProgramData\anaconda3\envs\streamlit39\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\ProgramData\anaconda3\envs\streamlit39\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
df
# Out:
#                                                  암호화요양기호         요양기관명  종별코드  \
# 0      JDQ4MTYyMiM1MSMkMSMkMCMkODkkMzgxMzUxIzExIyQxIy...  가톨릭대학교인천성모병원     1
# 1      JDQ4MTYyMiM1MSMkMSMkNCMkODkkMzgxMzUxIzExIyQxIy...        강릉아산병원     1
# 2      JDQ4MTg4MSM1MSMkMSMkMCMkODkkMzgxMzUxIzExIyQxIy...        강북삼성병원     1
# 3      JDQ4MTg4MSM1MSMkMSMkMCMkODkkMzgxMzUxIzExIyQxIy...       건국대학교병원     1
# 4      JDQ4MTYyMiM4MSMkMSMkMCMkODkkMzgxMzUxIzExIyQxIy...       경북대학교병원     1
# ...                                                  ...           ...   ...
# 76244  JDU4MTI3MSM1MSMkMSMkMCMkMTMkNDgxOTYxIzExIyQxIy...        힘나는한의원    93
# 76245  JDQ4MTg4MSM1MSMkMSMkNCMkMTMkNDgxOTYxIzUxIyQxIy...        힘내라한의원    93
# 76246  JDQ4MTg4MSM1MSMkMSMkNCMkMTMkNDgxMzUxIzUxIyQxIy...       힘찬마디한의원    93
# 76247  JDQ4MTg4MSM1MSMkMSMkNCMkMTMkMzgxNzAyIzUxIyQxIy...     힘찬세상경희한의원    93
# 76248  JDQ4MTYyMiM4MSMkMSMkNCMkMTMkNDgxMzUxIzMxIyQxIy...         힘찬한의원    93
#
#       종별코드명    시도코드 시도코드명   시군구코드 시군구코드명    읍면동   우편번호  ... 치과인턴 인원수  \
# 0      상급종합  220000    인천  220003  인천부평구    부평동  21431  ...        0
# 1      상급종합  320000    강원  320100    강릉시    NaN  25440  ...        0
# 2      상급종합  110000    서울  110016    종로구    NaN   3181  ...        0
# 3      상급종합  110000    서울  110023    광진구    NaN   5030  ...        0
# 4      상급종합  230000    대구  230006   대구중구    NaN  41944  ...        0
# ...     ...     ...   ...     ...    ...    ...    ...  ...      ...
# 76244   한의원  310000    경기  312300    김포시    NaN  10099  ...        0
# 76245   한의원  110000    서울  110003    강서구    NaN   7526  ...        0
# 76246   한의원  110000    서울  110002    강동구    천호동   5329  ...        0
# 76247   한의원  110000    서울  110014    용산구  한강로2가   4376  ...        0
# 76248   한의원  380000    경남  380500    진주시    NaN  52697  ...        0
#
#       치과레지던트 인원수 치과전문의 인원수  한방일반의 인원수  한방인턴 인원수  한방레지던트 인원수  한방전문의 인원수  \
# 0              0         1          0         0           0          0
# 1              0         2          0         0           0          0
# 2              0         4          0         0           0          0
# 3              0         3          0         0           0          0
# 4              0         1          0         0           0          0
# ...          ...       ...        ...       ...         ...        ...
# 76244          0         0          1         0           0          0
# 76245          0         0          2         0           0          0
# 76246          0         0          1         0           0          0
# 76247          0         0          0         0           0          1
# 76248          0         0          1         0           0          0
#
#        조산사 인원수       좌표(X)      좌표(Y)
# 0            0  126.724899  37.484831
# 1            0  128.857841  37.818433
# 2            0  126.967750  37.568408
# 3            0  127.071828  37.540376
# 4            0  128.604703  35.866253
# ...        ...         ...        ...
# 76244        0  126.704889  37.632495
# 76245        0  126.855061  37.561526
# 76246        0  127.126346  37.538174
# 76247        0  126.968167  37.530005
# 76248        0  128.064558  35.178636
#
# [76249 rows x 30 columns]

# %%
# 상급종합 병원 수의 히스토그램 그리기

# %%
df['종별코드명']=='상급종합'
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 76244    False
# 76245    False
# 76246    False
# 76247    False
# 76248    False
# Name: 종별코드명, Length: 76249, dtype: bool

# %%
df.loc[df['종별코드명']=='상급종합']
# Out:
#                                               암호화요양기호  \
# 0   JDQ4MTYyMiM1MSMkMSMkMCMkODkkMzgxMzUxIzExIyQxIy...
# 1   JDQ4MTYyMiM1MSMkMSMkNCMkODkkMzgxMzUxIzExIyQxIy...
# 2   JDQ4MTg4MSM1MSMkMSMkMCMkODkkMzgxMzUxIzExIyQxIy...
# 3   JDQ4MTg4MSM1MSMkMSMkMCMkODkkMzgxMzUxIzExIyQxIy...
# 4   JDQ4MTYyMiM4MSMkMSMkMCMkODkkMzgxMzUxIzExIyQxIy...
# 5   JDQ4MTYyMiM4MSMkMSMkNCMkODkkMzgxMzUxIzExIyQxIy...
# 6   JDQ4MTg4MSM1MSMkMSMkMCMkODkkMzgxMzUxIzExIyQxIy...
# 7   JDQ4MTYyMiM4MSMkMSMkMCMkODkkMzgxMzUxIzExIyQxIy...
# 8   JDQ4MTg4MSM1MSMkMSMkMCMkODkkMzgxMzUxIzExIyQxIy...
# 9   JDQ4MTYyMiM1MSMkMSMkMCMkODkkMzgxMzUxIzExIyQxIy...
# 10  JDQ4MTYyMiM2MSMkMSMkMiMkODkkMzgxMzUxIzExIyQxIy...
# 11  JDQ4MTYyMiM4MSMkMSMkMCMkODkkMzgxMzUxIzExIyQxIy...
# 12  JDQ4MTAxMiM1MSMkMSMkMCMkODkkMzgxMzUxIzExIyQyIy...
# 13  JDQ4MTAxMiM1MSMkMSMkMCMkODkkMzgxMzUxIzExIyQxIy...
# 14  JDQ4MTYyMiM1MSMkMSMkMCMkODkkMzgxMzUxIzExIyQxIy...
# 15  JDQ4MTg4MSM1MSMkMSMkMCMkODkkMzgxMzUxIzExIyQxIy...
# 16  JDQ4MTg4MSM1MSMkMSMkMCMkODkkMzgxMzUxIzExIyQxIy...
# 17  JDQ4MTYyMiM2MSMkMSMkMiMkODkkMzgxMzUxIzExIyQxIy...
# 18  JDQ4MTYyMiM1MSMkMSMkMCMkODkkMzgxMzUxIzExIyQxIy...
# 19  JDQ4MTYyMiM1MSMkMSMkMCMkODkkMzgxMzUxIzExIyQxIy...
# 20  JDQ4MTYyMiM4MSMkMSMkNCMkODkkMzgxMzUxIzExIyQxIy...
# 21  JDQ4MTYyMiM1MSMkMSMkNCMkODkkMzgxMzUxIzExIyQxIy...
# 22  JDQ4MTg4MSM1MSMkMSMkMCMkODkkMzgxMzUxIzExIyQxIy...
# 23  JDQ4MTg4MSM1MSMkMSMkMCMkODkkMzgxMzUxIzExIyQxIy...
# 24  JDQ4MTYyMiM4MSMkMSMkMCMkODkkMzgxMzUxIzExIyQxIy...
#
# max     1.0  380000.000000  381100.000000  61469.000000  2.010103e+07
#
#               총의사수  의과일반의 인원수    의과인턴 인원수  의과레지던트 인원수    의과전문의 인원수  ...  \
# count    45.000000  45.000000   45.000000   45.000000    45.000000  ...
# mean    511.355556   2.933333   45.288889  147.933333   303.822222  ...
# std     328.805079   4.030565   35.528236   96.221430   203.628928  ...
# min     206.000000   0.000000    0.000000   20.000000   163.000000  ...
# 25%     335.000000   0.000000   26.000000  101.000000   202.000000  ...
# 50%     403.000000   1.000000   37.000000  123.000000   232.000000  ...
# 75%     513.000000   4.000000   53.000000  159.000000   291.000000  ...
# max    1680.000000  17.000000  180.000000  547.000000  1046.000000  ...
#
#         치과인턴 인원수  치과레지던트 인원수  치과전문의 인원수  한방일반의 인원수  한방인턴 인원수  한방레지던트 인원수  \
# count  45.000000   45.000000  45.000000       45.0      45.0        45.0
# mean    1.222222    4.022222   5.088889        0.0       0.0         0.0
# std     2.275251    6.682708   4.176897        0.0       0.0         0.0
# min     0.000000    0.000000   0.000000        0.0       0.0         0.0
# 25%     0.000000    0.000000   2.000000        0.0       0.0         0.0
# 50%     0.000000    0.000000   4.000000        0.0       0.0         0.0
# 75%     2.000000    5.000000   7.000000        0.0       0.0         0.0
# max    10.000000   30.000000  17.000000        0.0       0.0         0.0
#
#        한방전문의 인원수    조산사 인원수       좌표(X)      좌표(Y)
# count  45.000000  45.000000   45.000000  45.000000
# mean    0.022222   0.044444  127.528579  36.659526
# std     0.149071   0.298142    0.836208   0.989605
# min     0.000000   0.000000  126.634096  35.059433
# 25%     0.000000   0.000000  126.960784  35.847097
# 50%     0.000000   0.000000  127.071828  37.318514
# 75%     0.000000   0.000000  128.480131  37.500944
# max     1.000000   2.000000  129.428912  37.818433
#
# [8 rows x 21 columns]

# %%
tgen_hos['총의사수'].describe()
# Out:
# count      45.000000
# mean      511.355556
# std       328.805079
# min       206.000000
# 25%       335.000000
# 50%       403.000000
# 75%       513.000000
# max      1680.000000
# Name: 총의사수, dtype: float64

# %%
plt.hist(data=tgen_hos, x='총의사수', rwidth=0.9, bins=20)
plt.show()

# %%
# 연습문제

# %%
df['시도코드명'] == '인천'
# Out:
# 0         True
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 76244    False
# 76245    False
# 76246    False
# 76247    False
# 76248    False
# Name: 시도코드명, Length: 76249, dtype: bool

# %%
df.loc[df['시도코드명'] == '인천']
# Out:
#                                                  암호화요양기호               요양기관명  \
# 0      JDQ4MTYyMiM1MSMkMSMkMCMkODkkMzgxMzUxIzExIyQxIy...        가톨릭대학교인천성모병원
# 26     JDQ4MTYyMiM1MSMkMSMkMCMkODkkMzgxMzUxIzExIyQyIy...      의료법인 길의료재단 길병원
# 29     JDQ4MTYyMiM1MSMkMSMkMCMkODkkMzgxMzUxIzExIyQxIy...       인하대학교의과대학부속병원
# 45     JDQ4MTYyMiM1MSMkMSMkMCMkODkkMzgxMzUxIzExIyQxIy...  (의)나사렛의료재단 나사렛국제병원
# 46     JDQ4MTYyMiM1MSMkMSMkMCMkODkkMzgxMzUxIzExIyQxIy...     (의)성세의료재단 뉴성민병원
# ...                                                  ...                 ...
# 76190  JDU4MTI3MSM1MSMkMSMkMCMkMTMkNDgxMzUxIzUxIyQxIy...                훈한의원
# 76206  JDQ4MTYyMiM1MSMkMSMkMCMkMTMkNDgxMzUxIzMxIyQxIy...                휴한의원
# 76216  JDQ4MTYyMiM1MSMkMSMkMCMkMTMkNDgxNzAyIzIxIyQxIy...               흑룡한의원
# 76220  JDQ4MTYyMiM1MSMkMSMkMCMkMTMkNDgxOTYxIzExIyQxIy...               흠당한의원
# 76234  JDU4MTI3MSM1MSMkMSMkMCMkMTMkMzgxNzAyIzExIyQyIy...               희성한의원
#
#        종별코드 종별코드명    시도코드 시도코드명   시군구코드  시군구코드명    읍면동   우편번호  ... 치과인턴 인원수  \
# 0         1  상급종합  220000    인천  220003   인천부평구    부평동  21431  ...        0
# 26        1  상급종합  220000    인천  220006   인천남동구    NaN  21565  ...        3
# 29        1  상급종합  220000    인천  220004    인천중구  신흥동3가  22332  ...        0
# 45       11  종합병원  220000    인천  220007   인천연수구    동춘동  21972  ...        0
# 46       11  종합병원  220000    인천  220005    인천서구    석남동  22789  ...        0
# ...     ...   ...     ...   ...     ...     ...    ...    ...  ...      ...
# 76190    93   한의원  220000    인천  220008   인천계양구    NaN  21065  ...        0
# 76206    93   한의원  220000    인천  220006   인천남동구    NaN  21574  ...        0
# 76216    93   한의원  220000    인천  220200   인천옹진군    NaN  23103  ...        0
# 76220    93   한의원  220000    인천  220001  인천미추홀구    NaN  22188  ...        0
# 76234    93   한의원  220000    인천  220003   인천부평구    NaN  21379  ...        0
#
#       치과레지던트 인원수 치과전문의 인원수  한방일반의 인원수  한방인턴 인원수  한방레지던트 인원수  한방전문의 인원수  \
# 0              0         1          0         0           0          0
# 26             3         6          0         0           0          0
# 29             0         3          0         0           0          0
# 45             0         0          1         0           0          2
# 46             0         0          0         0           0          0
# ...          ...       ...        ...       ...         ...        ...
# 76190          0         0          1         0           0          0
# 76206          0         0          1         0           0          0
# 76216          0         0          0         0           0          0
# 76220          0         0          1         0           0          0
# 76234          0         0          2         0           0          0
#
#        조산사 인원수       좌표(X)      좌표(Y)
# 0            0  126.724899  37.484831
# 26           0  126.709226  37.452171
# 29           0  126.634096  37.458679
# 45           0  126.670493  37.407958
# 46           0  126.669852  37.509775
# ...        ...         ...        ...
# 76190        0  126.738525  37.538151
# 76206        0  126.703214  37.443452
# 76216        0  124.665746  37.959671
# 76220        0  126.649258  37.447793
# 76234        0  127.115670  37.403709
#
# [3681 rows x 30 columns]

# %%
incheon = df.loc[df['시도코드명'] == '인천']

# %%
incheon['시군구코드명'].value_counts()
# Out:
# 시군구코드명
# 인천남동구     762
# 인천부평구     664
# 인천서구      584
# 인천미추홀구    483
# 인천연수구     460
# 인천계양구     380
# 인천중구      141
# 인천동구       92
# 인천강화군      87
# 인천옹진군      28
# Name: count, dtype: int64

# %%
data1 = incheon['시군구코드명'].value_counts()

# %%
data1.describe()
# Out:
# count     10.000000
# mean     368.100000
# std      265.331428
# min       28.000000
# 25%      104.250000
# 50%      420.000000
# 75%      558.750000
# max      762.000000
# Name: count, dtype: float64

# %%
data1
# Out:
# 시군구코드명
# 인천남동구     762
# 인천부평구     664
# 인천서구      584
# 인천미추홀구    483
# 인천연수구     460
# 인천계양구     380
# 인천중구      141
# 인천동구       92
# 인천강화군      87
# 인천옹진군      28
# Name: count, dtype: int64
